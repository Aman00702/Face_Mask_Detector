# %%
import tensorflow as tf
import cv2 
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
Datadirectory="dataset/" #training dataset
Classes=["with_mask","without_mask"]
for category in Classes:
    path=os.path.join(Datadirectory,category) 
    for img in os.listdir(path):  #os.listdir is for to get list of item from directory
        img_array=cv2.imread(os.path.join(path,img))
        plt.imshow(cv2.cvtColor(img_array,cv2.COLOR_BGR2RGB))
        plt.show()
        break
    break

# %%
img_size=224
new_array=cv2.resize(img_array,(img_size,img_size))
plt.imshow(cv2.cvtColor(new_array,cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # reading the images and converting all to array

# %%
Classes.index(category)
# Out:
# 0

# %%
training_Data=[] ##data
def create_training_Data():
    for category in Classes:
        path=os.path.join(Datadirectory,category)
        class_num=Classes.index(category)   ##0 1 , ## label
        for img in os.listdir(path):
            try:
                img_array= cv2.imread(os.path.join(path,img))
                new_array=cv2.resize(img_array,(img_size,img_size))
                training_Data.append([new_array,class_num])
            except Exception as e:
                pass

# %%
create_training_Data()

# %%
len(training_Data)
# Out:
# 3810

# %%
import random
random.shuffle(training_Data)

# %%
X=[]
y=[]

for features,label in training_Data:
    X.append(features)
    y.append(label)
    
X=np.array(X).reshape(-1,img_size,img_size,3)

# %%
# Out:
# array([[[118, 121, 135],
#         [122, 125, 139],
#         [124, 127, 141],
#         ...,
#         [ 76,  79,  93],
#         [ 73,  76,  90],
#         [ 71,  74,  88]],
#
#        [[117, 123, 136],
#         [120, 125, 138],
#         [122, 125, 139],
#         ...,
#         [ 80,  83,  97],
#         [ 71,  74,  88],
#         [ 64,  67,  81]],
#
#        [[119, 125, 138],
#         [119, 125, 138],
#         [112, 118, 131],
#         ...,
#         [ 74,  80,  93],
#         [ 74,  80,  93],
#         [ 67,  73,  86]],
#
#        ...,
#
#        [[ 41,  38,  23],
#         [ 41,  38,  23],
#         [ 41,  38,  23],
#         ...,
#         [155, 180, 206],
#         [154, 179, 205],
#         [155, 180, 206]],
#
#        [[ 41,  38,  23],
#         [ 41,  38,  23],
#         [ 41,  38,  23],
#         ...,
#         [155, 180, 206],
#         [155, 180, 206],
#         [155, 180, 206]],
#
#        [[ 42,  38,  23],
#         [ 41,  38,  23],
#         [ 41,  38,  23],
#         ...,
#         [155, 180, 206],
#         [155, 180, 206],
#         [155, 180, 206]]], dtype=uint8)
